# %% [markdown]
# <a href="https://colab.research.google.com/github/PicoRad-Imaging/SNM2024/blob/main/SNMMI2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the diffdrr and icecream packages
# !pip install diffdrr
# !pip show diffdrr
# !pip install icecream
# !pip install pytictoc

import matplotlib.pyplot as plt
import torch
import numpy as np
from google.colab import drive
from openpyxl import load_workbook
from diffdrr.drr import DRR
from diffdrr.data import load_example_ct
from diffdrr.visualization import plot_drr
from icecream import ic
from pytictoc import TicToc
t = TicToc() #create instance of class

# Read in the volume and get its origin and spacing in world coordinates
subject = load_example_ct()
ic(subject.volume)
ic(subject.spacing)

# Initialize the DRR module for generating synthetic X-rays
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Mount Google Drive
drive.mount('/content/drive')

# Path to the spreadsheet containing the camera geometry specifications
spreadsheet_path = '/content/drive/MyDrive/SPECTGeometry/MDSL.excel80M10RFR.cut-plate.008.150roi.2.30pin.105ellipse.xlsx'

# Load the workbook and select the appropriate worksheet
wb = load_workbook(filename=spreadsheet_path, data_only=True)
wb.active = 1  # Assuming the relevant sheet is the second one (index 1)
ws = wb.active

# Read lcoll values from the spreadsheet
lcoll = np.array([ws.cell(row=i, column=7).value for i in range(3, 83)])
vsdr = 5. * lcoll  # Example operation on lcoll values

# Read alpha and beta values from the spreadsheet (in radians)
alpha = [ws.cell(row=i, column=22).value - (np.pi/2.) for i in range(3, 83)]
beta = [ws.cell(row=i, column=23).value for i in range(3, 83)]

# Define parameters for DRR generation
HEIGHT = 250
DELX = 1.0

# Initialize the projections array for Wide and FOV cases
projections = np.zeros((80, 250, 250))

t.tic() #Start timer
# Generate DRRs for all 80 cameras with DELX=1.0
for camera_idx in range(80):
    SDR = float(vsdr[camera_idx])
    true_params = {
        "sdr": SDR,
        "alpha": alpha[camera_idx],
        "beta": beta[camera_idx],
        "gamma": 0.0,
        "bx": 0.,
        "by": float(vsdr[camera_idx]),
        "bz": 0.,
    }
    device = "cuda" if torch.cuda.is_available() else "cpu"
    drr = DRR(subject, sdd=SDR, height=HEIGHT, delx=DELX).to(device)
    rotations = torch.tensor(
      [
        [
            true_params["alpha"],
            true_params["beta"],
            true_params["gamma"],
        ]
      ]
    ).to(device)
    translations = torch.tensor(
      [
        [
            true_params["bx"],
            true_params["by"],
            true_params["bz"],
        ]
      ]
    ).to(device)
    ground_truth = drr(
        rotations,
        translations,
        parameterization="euler_angles",
        convention="ZXY",
    )
    ic(camera_idx)
    projections[camera_idx, :, :] = ground_truth.squeeze().cpu().numpy()

t.toc() #Time elapsed since t.tic()
ic(projections.shape)

# Initialize the projections array for ExtraWide case
projections_extra_wide = np.zeros((80, 250, 250))

# Generate DRRs for all 80 cameras with DELX=2.0
for camera_idx in range(80):
    SDD = float(vsdr[camera_idx]) # 10x scale for 50mm x 50mm at lcol
    true_params = {
        "sdd": SDD,
        "alpha": alpha[camera_idx],
        "beta": beta[camera_idx],
        "gamma": 0.0,
        "bx": 0.,
        "by": float(vsdr[camera_idx]),
        "bz": 0.,
    }
    device = "cuda" if torch.cuda.is_available() else "cpu"
    drr = DRR(subject, sdd=SDD, height=HEIGHT, delx=2.0).to(device)
    drr_wide= DRR(subject, sdd=SDD, height=HEIGHT, delx=4.0).to(device)
    rotations = torch.tensor(
      [
        [
            true_params["alpha"],
            true_params["beta"],
            true_params["gamma"],
        ]
      ]
    ).to(device)
    translations = torch.tensor(
      [
        [
            true_params["bx"],
            true_params["by"],
            true_params["bz"],
        ]
      ]
    ).to(device)
    ground_truth = drr(
        rotations,
        translations,
        parameterization="euler_angles",
        convention="ZXY",
    )
    ic(camera_idx)
    projections_extra_wide[camera_idx, :, :] = ground_truth.squeeze().cpu().numpy()

# Function to add a white box overlay
def add_fov_box(ax, width, height):
    rect = plt.Rectangle((125 - width // 2, 125 - height // 2), width, height, linewidth=1, edgecolor='white', facecolor='none')
    ax.add_patch(rect)

# Display central 128x128 pixels (FOV)
fig, axes = plt.subplots(nrows=4, ncols=20, figsize=(20, 4), gridspec_kw={'wspace': 0, 'hspace': 0})
for i, ax in enumerate(axes.flat):
    ax.imshow(projections[i][61:189, 61:189], cmap='gray')
    ax.axis('off')
plt.suptitle('FOV')
plt.show()

# Display projections with WideFOV
fig, axes = plt.subplots(nrows=4, ncols=20, figsize=(20, 4), gridspec_kw={'wspace': 0, 'hspace': 0})
for i, ax in enumerate(axes.flat):
    ax.imshow(projections[i], cmap='gray')
    add_fov_box(ax, 124, 124)  # Central 124x124 pixels
    ax.axis('off')
plt.suptitle('WideFOV')
plt.show()

# Display projections with ExtraWideFOV
fig, axes = plt.subplots(nrows=4, ncols=20, figsize=(20, 4), gridspec_kw={'wspace': 0, 'hspace': 0})
for i, ax in enumerate(axes.flat):
    ax.imshow(projections_extra_wide[i], cmap='gray')
    add_fov_box(ax, 64, 64)  # Central 64x64 pixels
    ax.axis('off')
plt.suptitle('ExtraWideFOV')
plt.show()
# Out:
# Requirement already satisfied: diffdrr in /usr/local/lib/python3.10/dist-packages (0.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from diffdrr) (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from diffdrr) (0.13.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from diffdrr) (4.66.4)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from diffdrr) (2.31.6)
# Requirement already satisfied: fastcore in /usr/local/lib/python3.10/dist-packages (from diffdrr) (1.5.38)
# Requirement already satisfied: pyvista[all] in /usr/local/lib/python3.10/dist-packages (from diffdrr) (0.43.8)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from diffdrr) (0.8.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from diffdrr) (0.18.0+cu121)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from diffdrr) (1.11.4)
# Requirement already satisfied: torchio in /usr/local/lib/python3.10/dist-packages (from diffdrr) (0.19.6)
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (from diffdrr) (1.0.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from diffdrr) (2.3.0+cu121)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastcore->diffdrr) (24.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio->diffdrr) (1.25.2)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio->diffdrr) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->diffdrr) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->diffdrr) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->diffdrr) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->diffdrr) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->diffdrr) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->diffdrr) (2.8.2)
# Requirement already satisfied: pooch in /usr/local/lib/python3.10/dist-packages (from pyvista[all]->diffdrr) (1.8.1)
# Requirement already satisfied: scooby>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from pyvista[all]->diffdrr) (0.10.0)
# Requirement already satisfied: vtk in /usr/local/lib/python3.10/dist-packages (from pyvista[all]->diffdrr) (9.3.0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn->diffdrr) (2.0.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm->diffdrr) (6.0.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from timm->diffdrr) (0.23.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm->diffdrr) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->diffdrr) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->diffdrr) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->diffdrr) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->diffdrr) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->diffdrr) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->diffdrr) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->diffdrr) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->diffdrr) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->diffdrr) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->diffdrr) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->diffdrr) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->diffdrr) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->diffdrr) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->diffdrr) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->diffdrr) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->diffdrr) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->diffdrr) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->diffdrr) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->diffdrr) (12.5.40)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.10/dist-packages (from torchio->diffdrr) (1.2.14)
# Requirement already satisfied: SimpleITK!=2.0.*,!=2.1.1.1 in /usr/local/lib/python3.10/dist-packages (from torchio->diffdrr) (2.3.1)
# Requirement already satisfied: humanize in /usr/local/lib/python3.10/dist-packages (from torchio->diffdrr) (4.7.0)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (from torchio->diffdrr) (4.0.2)
# Requirement already satisfied: typer[all] in /usr/local/lib/python3.10/dist-packages (from torchio->diffdrr) (0.9.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn->diffdrr) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn->diffdrr) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->diffdrr) (1.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated->torchio->diffdrr) (1.14.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm->diffdrr) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->diffdrr) (2.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nibabel->torchio->diffdrr) (67.7.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch->pyvista[all]->diffdrr) (4.2.2)
# Requirement already satisfied: cmocean in /usr/local/lib/python3.10/dist-packages (from pyvista[all]->diffdrr) (4.0.3)
# Requirement already satisfied: colorcet in /usr/local/lib/python3.10/dist-packages (from pyvista[all]->diffdrr) (3.1.0)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from pyvista[all]->diffdrr) (7.7.1)
# Requirement already satisfied: jupyter-server-proxy in /usr/local/lib/python3.10/dist-packages (from pyvista[all]->diffdrr) (4.1.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from pyvista[all]->diffdrr) (1.6.0)
# Requirement already satisfied: trame>=2.5.2 in /usr/local/lib/python3.10/dist-packages (from pyvista[all]->diffdrr) (3.6.0)
# Requirement already satisfied: trame-client>=2.12.7 in /usr/local/lib/python3.10/dist-packages (from pyvista[all]->diffdrr) (3.0.3)
# Requirement already satisfied: trame-server>=2.11.7 in /usr/local/lib/python3.10/dist-packages (from pyvista[all]->diffdrr) (3.0.0)
# Requirement already satisfied: trame-vtk>=2.5.8 in /usr/local/lib/python3.10/dist-packages (from pyvista[all]->diffdrr) (2.8.8)
# Requirement already satisfied: trame-vuetify>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from pyvista[all]->diffdrr) (2.5.0)
# Requirement already satisfied: meshio>=5.2 in /usr/local/lib/python3.10/dist-packages (from pyvista[all]->diffdrr) (5.3.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->diffdrr) (1.3.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer[all]->torchio->diffdrr) (8.1.7)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from typer[all]->torchio->diffdrr) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]->torchio->diffdrr) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]->torchio->diffdrr) (13.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm->diffdrr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm->diffdrr) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm->diffdrr) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm->diffdrr) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]->torchio->diffdrr) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]->torchio->diffdrr) (2.16.1)
# Requirement already satisfied: wslink<3,>=2 in /usr/local/lib/python3.10/dist-packages (from trame-server>=2.11.7->pyvista[all]->diffdrr) (2.0.4)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from trame-server>=2.11.7->pyvista[all]->diffdrr) (10.1.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->pyvista[all]->diffdrr) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->pyvista[all]->diffdrr) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->pyvista[all]->diffdrr) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->pyvista[all]->diffdrr) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->pyvista[all]->diffdrr) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->pyvista[all]->diffdrr) (3.0.10)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from jupyter-server-proxy->pyvista[all]->diffdrr) (3.9.5)
# Requirement already satisfied: jupyter-server>=1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server-proxy->pyvista[all]->diffdrr) (1.24.0)
# Requirement already satisfied: simpervisor>=1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server-proxy->pyvista[all]->diffdrr) (1.0.0)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-server-proxy->pyvista[all]->diffdrr) (6.3.3)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->pyvista[all]->diffdrr) (6.1.12)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->pyvista[all]->diffdrr) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->pyvista[all]->diffdrr) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->pyvista[all]->diffdrr) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->pyvista[all]->diffdrr) (3.0.43)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->pyvista[all]->diffdrr) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->pyvista[all]->diffdrr) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->pyvista[all]->diffdrr) (4.9.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (3.7.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (23.1.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (5.7.2)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (6.5.4)
# Requirement already satisfied: nbformat>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (5.10.4)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (0.20.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (24.0.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (0.18.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (1.8.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]->torchio->diffdrr) (0.1.2)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->pyvista[all]->diffdrr) (6.5.5)
# Requirement already satisfied: msgpack<2,>=1 in /usr/local/lib/python3.10/dist-packages (from wslink<3,>=2->trame-server>=2.11.7->pyvista[all]->diffdrr) (1.0.8)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr) (4.0.3)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (1.2.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->pyvista[all]->diffdrr) (0.8.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.2.0->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.2.0->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (4.19.2)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyvista[all]->diffdrr) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->pyvista[all]->diffdrr) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->pyvista[all]->diffdrr) (0.2.13)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (21.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.2.0->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.2.0->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.2.0->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (0.18.1)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyvista[all]->diffdrr) (0.2.4)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=6.4.4->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.0->jupyter-server-proxy->pyvista[all]->diffdrr) (2.22)
# Name: diffdrr
# Version: 0.4.0
# Summary: Auto-differentiable digitally reconstructed radiographs in PyTorch
# Home-page: https://github.com/eigenvivek/DiffDRR
# Author: Vivek Gopalakrishnan
# Author-email: vivekg@mit.edu
# License: MIT License
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: einops, fastcore, imageio, matplotlib, pyvista, scipy, seaborn, timm, torch, torchio, torchvision, tqdm
# Required-by:
# Requirement already satisfied: icecream in /usr/local/lib/python3.10/dist-packages (2.1.3)
# Requirement already satisfied: colorama>=0.3.9 in /usr/local/lib/python3.10/dist-packages (from icecream) (0.4.6)
# Requirement already satisfied: pygments>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from icecream) (2.16.1)
# Requirement already satisfied: executing>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from icecream) (2.0.1)
# Requirement already satisfied: asttokens>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from icecream) (2.4.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from asttokens>=2.0.1->icecream) (1.16.0)
# Requirement already satisfied: pytictoc in /usr/local/lib/python3.10/dist-packages (1.5.3)
# ic| subject.volume: ScalarImage(shape: (1, 512, 512, 133); spacing: (0.70, 0.70, 2.50); orientation: RAS+; dtype: torch.FloatTensor; memory: 133.0 MiB)
# ic| subject.spacing: (0.703125, 0.703125, 2.5)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ic| camera_idx: 0
# ic| camera_idx: 1
# ic| camera_idx: 2
# ic| camera_idx: 3
# ic| camera_idx: 4
# ic| camera_idx: 5
# ic| camera_idx: 6
# ic| camera_idx: 7
# ic| camera_idx: 8
# ic| camera_idx: 9
# ic| camera_idx: 10
# ic| camera_idx: 11
# ic| camera_idx: 12
# ic| camera_idx: 13
# ic| camera_idx: 14
# ic| camera_idx: 15
# ic| camera_idx: 16
# ic| camera_idx: 17
# ic| camera_idx: 18
# ic| camera_idx: 19
# ic| camera_idx: 20
# ic| camera_idx: 21
# ic| camera_idx: 22
# ic| camera_idx: 23
# ic| camera_idx: 24
# ic| camera_idx: 25
# ic| camera_idx: 26
# ic| camera_idx: 27
# ic| camera_idx: 28
# ic| camera_idx: 29
# ic| camera_idx: 30
# ic| camera_idx: 31
# ic| camera_idx: 32
# ic| camera_idx: 33
# ic| camera_idx: 34
# ic| camera_idx: 35
# ic| camera_idx: 36
# ic| camera_idx: 37
# ic| camera_idx: 38
# ic| camera_idx: 39
# ic| camera_idx: 40
# ic| camera_idx: 41
# ic| camera_idx: 42
# ic| camera_idx: 43
# ic| camera_idx: 44
# ic| camera_idx: 45
# ic| camera_idx: 46
# ic| camera_idx: 47
# ic| camera_idx: 48
# ic| camera_idx: 49
# ic| camera_idx: 50
# ic| camera_idx: 51
# ic| camera_idx: 52
# ic| camera_idx: 53
# ic| camera_idx: 54
# ic| camera_idx: 55
# ic| camera_idx: 56
# ic| camera_idx: 57
# ic| camera_idx: 58
# ic| camera_idx: 59
# ic| camera_idx: 60
# ic| camera_idx: 61
# ic| camera_idx: 62
# ic| camera_idx: 63
# ic| camera_idx: 64
# ic| camera_idx: 65
# ic| camera_idx: 66
# ic| camera_idx: 67
# ic| camera_idx: 68
# ic| camera_idx: 69
# ic| camera_idx: 70
# ic| camera_idx: 71
# ic| camera_idx: 72
# ic| camera_idx: 73
# ic| camera_idx: 74
# ic| camera_idx: 75
# ic| camera_idx: 76
# ic| camera_idx: 77
# ic| camera_idx: 78
# ic| camera_idx: 79
# ic| projections.shape: (80, 250, 250)
# Elapsed time is 17.730241 seconds.
# ic| camera_idx: 0
# ic| camera_idx: 1
# ic| camera_idx: 2
# ic| camera_idx: 3
# ic| camera_idx: 4
# ic| camera_idx: 5
# ic| camera_idx: 6
# ic| camera_idx: 7
# ic| camera_idx: 8
# ic| camera_idx: 9
# ic| camera_idx: 10
# ic| camera_idx: 11
# ic| camera_idx: 12
# ic| camera_idx: 13
# ic| camera_idx: 14
# ic| camera_idx: 15
# ic| camera_idx: 16
# ic| camera_idx: 17
# ic| camera_idx: 18
# ic| camera_idx: 19
# ic| camera_idx: 20
# ic| camera_idx: 21
# ic| camera_idx: 22
# ic| camera_idx: 23
# ic| camera_idx: 24
# ic| camera_idx: 25
# ic| camera_idx: 26
# ic| camera_idx: 27
# ic| camera_idx: 28
# ic| camera_idx: 29
# ic| camera_idx: 30
# ic| camera_idx: 31
# ic| camera_idx: 32
# ic| camera_idx: 33
# ic| camera_idx: 34
# ic| camera_idx: 35
# ic| camera_idx: 36
# ic| camera_idx: 37
# ic| camera_idx: 38
# ic| camera_idx: 39
# ic| camera_idx: 40
# ic| camera_idx: 41
# ic| camera_idx: 42
# ic| camera_idx: 43
# ic| camera_idx: 44
# ic| camera_idx: 45
# ic| camera_idx: 46
# ic| camera_idx: 47
# ic| camera_idx: 48
# ic| camera_idx: 49
# ic| camera_idx: 50
# ic| camera_idx: 51
# ic| camera_idx: 52
# ic| camera_idx: 53
# ic| camera_idx: 54
# ic| camera_idx: 55
# ic| camera_idx: 56
# ic| camera_idx: 57
# ic| camera_idx: 58
# ic| camera_idx: 59
# ic| camera_idx: 60
# ic| camera_idx: 61
# ic| camera_idx: 62
# ic| camera_idx: 63
# ic| camera_idx: 64
# ic| camera_idx: 65
# ic| camera_idx: 66
# ic| camera_idx: 67
# ic| camera_idx: 68
# ic| camera_idx: 69
# ic| camera_idx: 70
# ic| camera_idx: 71
# ic| camera_idx: 72
# ic| camera_idx: 73
# ic| camera_idx: 74
# ic| camera_idx: 75
# ic| camera_idx: 76
# ic| camera_idx: 77
# ic| camera_idx: 78
# ic| camera_idx: 79
